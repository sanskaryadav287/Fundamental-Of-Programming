# %% [markdown]
# Conditional statement
# Python Conditions and If statements Python supports the usual logical conditions from mathematics:
#
# • Equals: a == b
#
# • Not Equals: a != b
#
# • Less than: a < b
#
# • Less than or equal to: a <= b
#
# • Greater than: a > b
#
# • Greater than or equal to: a >= b
#
# These conditions can be used in several ways, most commonly in "if statements" and loops.
#
# An "if statement" is written by using the if keyword.

# %% [markdown]
# Q1. Check if a number is positive or negative.

# %%
num = -5
if num > 0:
    print("Positive")
else:
    print("Negative")
# Out:
# Negative

# %% [markdown]
# Q2. Check if a number is even or odd.

# %%
num = 12
if num % 2 == 0:
    print("Even")
else:
    print("Odd")

# %% [markdown]
# Q3. Check if a person is eligible to vote (age ≥ 18).

# %%
age = 20
if age >= 18:
    print("Eligible to vote")
else:
    print("Not eligible")

# %% [markdown]
# Q4. Find the greatest of two numbers.

# %%
a, b = 15, 10
if a > b:
    print("a is greater")
else:
    print("b is greater")

# %% [markdown]
# Q5. Find the greatest of three numbers.

# %%
a, b, c = 12, 25, 9
if a > b and a > c:
    print("a is greatest")
elif b > c:
    print("b is greatest")
else:
    print("c is greatest")

# %% [markdown]
# Q6. Check if a number is divisible by 5.

# %%
num = 20
if num % 5 == 0:
    print("Divisible by 5")
else:
    print("Not divisible by 5")

# %% [markdown]
# Q7. Check whether a character is a vowel or consonant.

# %%
ch = "e"
if ch in "aeiouAEIOU":
    print("Vowel")
else:
    print("Consonant")

# %% [markdown]
# Q8. Check grade of a student based on marks.

# %%
marks = 78
if marks >= 90:
    print("Grade A")
elif marks >= 75:
    print("Grade B")
elif marks >= 50:
    print("Grade C")
else:
    print("Fail")

# %% [markdown]
# Q9. Check if a number is within a range (10 to 50).

# %%
num = 25
if 10 <= num <= 50:
    print("Within range")
else:
    print("Out of range")

# %% [markdown]
# Q10. Check if a number is multiple of both 3 and 7.

# %%
num = 21
if num % 3 == 0 and num % 7 == 0:
    print("Multiple of both 3 and 7")
else:
    print("Not a multiple of both")
