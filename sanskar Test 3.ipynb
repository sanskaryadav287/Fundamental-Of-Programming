# %% [markdown]
# ## 1

# %%
list=["red","Yellow","Blue","Green","Pink"]
print(list[3])
# Out:
# Green

# %% [markdown]
# ## 2

# %%
l1=[50,60,70,80]
l1[0]="55"
print(l1)
# Out:
# ['55', 60, 70, 80]

# %% [markdown]
# ## 3

# %%
x=True
y=False
x==y
# Out:
# False

# %% [markdown]
# ## 4

# %%
x=15
x>10 and x<50
# Out:
# True

# %% [markdown]
# ## 5

# %%
a=45
a+=67
a
# Out:
# 112

# %% [markdown]
# ## 6

# %%
x=5
y=2
5>10 or 2<8
# Out:
# True

# %% [markdown]
# ## 7

# %%
dist={"name":"Bob","Age":30}
print(dist["Age"])
# Out:
# 30

# %% [markdown]
# ## 8

# %%
dist1={"Name":"Akku","Gender":"M","Age":20,"Phone":"74454645454"}
print(dist1)
# Out:
# {'Name': 'Akku', 'Gender': 'M', 'Age': 20, 'Phone': '74454645454'}
