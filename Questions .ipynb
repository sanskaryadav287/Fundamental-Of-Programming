# %% [markdown]
# ## 1.

# %%
person={"Name":"Ashiv","Age":20}
person
# Out:
# {'Name': 'Ashiv', 'Age': 20}

# %%
type(person)
# Out:
# dict

# %%
person["Age"]
# Out:
# 20

# %% [markdown]
# ## 2.

# %%
person["Course"]="Data science"
person
# Out:
# {'Name': 'Ashiv', 'Age': 20, 'Course': 'Data science'}

# %%
person["City"]="New York"
person
# Out:
# {'Name': 'Ashiv', 'Age': 20, 'Course': 'Data science', 'City': 'New York'}

# %%
person["City"]="Bulandsahar"
person
# Out:
# {'Name': 'Ashiv', 'Age': 20, 'Course': 'Data science', 'City': 'Bulandsahar'}

# %% [markdown]
# ## 3

# %%
person={"Name":"Amir","Age":20,"City":"New York"}
del person["City"]
print(person)
# Out:
# {'Name': 'Amir', 'Age': 20}

# %% [markdown]
# ## 4.

# %%
len(person)
# Out:
# 2

# %%
person
# Out:
# {'Name': 'Amir', 'Age': 20}

# %% [markdown]
# ## 5.

# %%
person["city"]="Unknow"
person
# Out:
# {'Name': 'Amir', 'Age': 20, 'city': 'Unknow'}

# %% [markdown]
# ## 6.

# %%
person={"Name":"aMIR","Age":20}
city=person.get("city","unknown")
print(city)
# Out:
# unknown
